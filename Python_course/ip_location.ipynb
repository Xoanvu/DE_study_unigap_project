# %%
from pymongo import MongoClient
import ip2location
import csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from pymongo import MongoClient
#       2 import ip2location
#       3 import csv
#
# ModuleNotFoundError: No module named 'pymongo'
