# %%
from pymongo import MongoClient
import IP2Location
import csv

# %%
from pymongo import MongoClient
url = "mongodb://admin:Poiuytrewq%4012@35.240.135.255:28018/?authSource=admin"
client = MongoClient(url)
print(client.server_info())
# Out:
# {'version': '7.0.25', 'gitVersion': '96dce3da49b8d2e9e0d328048cb56930eb1bdb2b', 'modules': [], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [7, 0, 25, 0], 'openssl': {'running': 'OpenSSL 3.0.17 1 Jul 2025', 'compiled': 'OpenSSL 3.0.16 11 Feb 2025'}, 'buildEnvironment': {'distmod': 'debian12', 'distarch': 'x86_64', 'cc': '/opt/mongodbtoolchain/v4/bin/gcc: gcc (GCC) 11.3.0', 'ccflags': '-Werror -include mongo/platform/basic.h -ffp-contract=off -fasynchronous-unwind-tables -g2 -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -gdwarf-5 -fno-omit-frame-pointer -fno-strict-aliasing -O2 -march=sandybridge -mtune=generic -mprefer-vector-width=128 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -gdwarf64 -Wa,--nocompress-debug-sections -fno-builtin-memcmp -Wimplicit-fallthrough=5', 'cxx': '/opt/mongodbtoolcha
# ...

# %%
def process_ip_locations():
    # 1. Kết nối MongoDB
    client = MongoClient("mongodb://admin:Poiuytrewq%4012@35.240.135.255:28018/?authSource=admin")
    db = client["mydb"]
    collection = db["summary"]
    print("Các index hiện có trong collection 'summary':")
    for index in collection.list_indexes():
        print(index)

process_ip_locations()
# Out:
# Các index hiện có trong collection 'summary':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
